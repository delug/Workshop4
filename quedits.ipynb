# %%
import torch
from torch.nn import functional as F

# %%
from torchvision import datasets, transforms

#gets training and testing data for MNIST dataset
trainData = datasets.MNIST('data/', train = True, transform = transforms.ToTensor(), download=False)
testData = datasets.MNIST('data/', train = False, transform = transforms.ToTensor(), download=False)

#constructs loaders from datasets
trainLoader = torch.utils.data.DataLoader(trainData, batch_size=100, shuffle=True)
testLoader = torch.utils.data.DataLoader(testData, batch_size=100, shuffle=True)

# %%
class Perceptron():
    def __init__(self, classVal, learningRate):
        self.weights = torch.randn((784))
        self.classVal = classVal
        self.learningRate = learningRate
    def forward(self, x):
        sum = torch.empty((x.shape[0]))
        for i in range(x.shape[0]):
            sum[i] = torch.dot(self.weights, x[i].reshape(-1))
        return torch.sigmoid(sum)
    def loss(self, y, p):
        loss = torch.empty_like(p)
        for i in range(p.shape[0]):
            if y[i] == self.classVal:
                target = 1
            else:
                target = 0
            loss[i] = (p[i] - target) * (p[i] - target)
        return loss
    def update(self, x, y, p):
        sum = torch.zeros(x.shape[2]*x.shape[3])
        for i in range(p.shape[0]):
            mseJac = 2 * (y[i] - p[i])
            sigmoidJac = p[i] * (1 - p[i])
            weightJac = x[i].reshape(-1)
            sum += mseJac * sigmoidJac * weightJac
        sum /= p.shape[0]
        for i in range(self.weights.shape[0]):
            self.weights[i] -= self.learningRate * sum[i]
            
model = Perceptron(0, 1e-3)

# %%
def train(epoch):
    trainingLoss = 0
    for index, (data, target) in enumerate(trainLoader):
        predictions = model.forward(data)
        batchLoss = torch.sum(model.loss(target, predictions))
        trainingLoss += batchLoss
        model.update(data, target, predictions)
        if index % 10 == 0:
            print(f'Training Epoch: {epoch} [{index * len(data)} / {len(trainData)}]\tLoss: {(batchLoss / len(data)):.6f}')
    print(f'----- Epoch: {epoch} Average loss: {(trainingLoss/len(trainData)):.4f}')
    
def test():
    testingLoss = 0
    for index, (data, target) in enumerate(testLoader):
        predictions = model.forward(data)
        testingLoss += torch.sum(model.loss(target, predictions))
    print(f'----- Test set loss: {(testingLoss):.4f}')

# %%
for epoch in range(1, 11):
    train(epoch)
    test()
# Out:
# Training Epoch: 1 [0 / 60000]	Loss: 0.347160
# Training Epoch: 1 [1000 / 60000]	Loss: 0.400972
# Training Epoch: 1 [2000 / 60000]	Loss: 0.363420
# Training Epoch: 1 [3000 / 60000]	Loss: 0.405137
# Training Epoch: 1 [4000 / 60000]	Loss: 0.336282
# Training Epoch: 1 [5000 / 60000]	Loss: 0.453686
# Training Epoch: 1 [6000 / 60000]	Loss: 0.412183
# Training Epoch: 1 [7000 / 60000]	Loss: 0.352086
# Training Epoch: 1 [8000 / 60000]	Loss: 0.297770
# Training Epoch: 1 [9000 / 60000]	Loss: 0.402057
# Training Epoch: 1 [10000 / 60000]	Loss: 0.367766
# Training Epoch: 1 [11000 / 60000]	Loss: 0.304151
# Training Epoch: 1 [12000 / 60000]	Loss: 0.318557
# Training Epoch: 1 [13000 / 60000]	Loss: 0.454694
# Training Epoch: 1 [14000 / 60000]	Loss: 0.285229
# Training Epoch: 1 [15000 / 60000]	Loss: 0.329588
# Training Epoch: 1 [16000 / 60000]	Loss: 0.277692
# Training Epoch: 1 [17000 / 60000]	Loss: 0.307911
# Training Epoch: 1 [18000 / 60000]	Loss: 0.243777
# Training Epoch: 1 [19000 / 60000]	Loss: 0.232328
# Training Epoch: 1 [20000 / 60000]	Loss: 0.223998
# Training Epoch: 1 [21000 / 60000]	Loss: 0.319527
# Training Epoch: 1 [22000 / 60000]	Loss: 0.173020
# Training Epoch: 1 [23000 / 60000]	Loss: 0.267395
# Training Epoch: 1 [24000 / 60000]	Loss: 0.253899
# Training Epoch: 1 [25000 / 60000]	Loss: 0.255938
# Training Epoch: 1 [26000 / 60000]	Loss: 0.217933
# Training Epoch: 1 [27000 / 60000]	Loss: 0.303272
# Training Epoch: 1 [28000 / 60000]	Loss: 0.247574
# Training Epoch: 1 [29000 / 60000]	Loss: 0.194146
# Training Epoch: 1 [30000 / 60000]	Loss: 0.160897
# Training Epoch: 1 [31000 / 60000]	Loss: 0.205001
# Training Epoch: 1 [32000 / 60000]	Loss: 0.173000
# Training Epoch: 1 [33000 / 60000]	Loss: 0.213025
# Training Epoch: 1 [34000 / 60000]	Loss: 0.191426
# Training Epoch: 1 [35000 / 60000]	Loss: 0.124024
# Training Epoch: 1 [36000 / 60000]	Loss: 0.151551
# Training Epoch: 1 [37000 / 60000]	Loss: 0.174332
# Training Epoch: 1 [38000 / 60000]	Loss: 0.100329
# Training Epoch: 1 [39000 / 60000]	Loss: 0.143017
# Training Epoch: 1 [40000 / 60000]	Loss: 0.139787
# Training Epoch: 1 [41000 / 60000]	Loss: 0.133391
# Training Epoch: 1 [42000 / 60000]	Loss: 0.140961
# Training Epoch: 1 [43000 / 60000]	Loss: 0.140820
# Training Epoch: 1 [44000 / 60000]	Loss: 0.139203
# Training Epoch: 1 [45000 / 60000]	Loss: 0.125126
# Training Epoch: 1 [46000 / 60000]	Loss: 0.205075
# Training Epoch: 1 [47000 / 60000]	Loss: 0.199280
# Training Epoch: 1 [48000 / 60000]	Loss: 0.171952
# Training Epoch: 1 [49000 / 60000]	Loss: 0.121455
# Training Epoch: 1 [50000 / 60000]	Loss: 0.113405
# Training Epoch: 1 [51000 / 60000]	Loss: 0.189145
# Training Epoch: 1 [52000 / 60000]	Loss: 0.191370
# Training Epoch: 1 [53000 / 60000]	Loss: 0.129351
# Training Epoch: 1 [54000 / 60000]	Loss: 0.133543
# Training Epoch: 1 [55000 / 60000]	Loss: 0.152070
# Training Epoch: 1 [56000 / 60000]	Loss: 0.150943
# Training Epoch: 1 [57000 / 60000]	Loss: 0.137146
# Training Epoch: 1 [58000 / 60000]	Loss: 0.096896
# Training Epoch: 1 [59000 / 60000]	Loss: 0.067955
# ----- Epoch: 1 Average loss: 0.2199
# ----- Test set loss: 1154.5336
# Training Epoch: 2 [0 / 60000]	Loss: 0.121001
# Training Epoch: 2 [1000 / 60000]	Loss: 0.107769
# Training Epoch: 2 [2000 / 60000]	Loss: 0.110349
# Training Epoch: 2 [3000 / 60000]	Loss: 0.127914
# Training Epoch: 2 [4000 / 60000]	Loss: 0.117934
# Training Epoch: 2 [5000 / 60000]	Loss: 0.104089
# Training Epoch: 2 [6000 / 60000]	Loss: 0.064275
# Training Epoch: 2 [7000 / 60000]	Loss: 0.085804
# Training Epoch: 2 [8000 / 60000]	Loss: 0.131952
# Training Epoch: 2 [9000 / 60000]	Loss: 0.118890
# Training Epoch: 2 [10000 / 60000]	Loss: 0.144529
# Training Epoch: 2 [11000 / 60000]	Loss: 0.126348
# Training Epoch: 2 [12000 / 60000]	Loss: 0.129047
# Training Epoch: 2 [13000 / 60000]	Loss: 0.112442
# Training Epoch: 2 [14000 / 60000]	Loss: 0.087573
# Training Epoch: 2 [15000 / 60000]	Loss: 0.105146
# Training Epoch: 2 [16000 / 60000]	Loss: 0.094993
# Training Epoch: 2 [17000 / 60000]	Loss: 0.069063
# Training Epoch: 2 [18000 / 60000]	Loss: 0.111379
# Training Epoch: 2 [19000 / 60000]	Loss: 0.139635
# Training Epoch: 2 [20000 / 60000]	Loss: 0.083620
# Training Epoch: 2 [21000 / 60000]	Loss: 0.097736
# Training Epoch: 2 [22000 / 60000]	Loss: 0.091491
# Training Epoch: 2 [23000 / 60000]	Loss: 0.085969
# Training Epoch: 2 [24000 / 60000]	Loss: 0.075394
# Training Epoch: 2 [25000 / 60000]	Loss: 0.113424
# Training Epoch: 2 [26000 / 60000]	Loss: 0.114844
# Training Epoch: 2 [27000 / 60000]	Loss: 0.142676
# Training Epoch: 2 [28000 / 60000]	Loss: 0.078361
# Training Epoch: 2 [29000 / 60000]	Loss: 0.107531
# Training Epoch: 2 [30000 / 60000]	Loss: 0.114204
# Training Epoch: 2 [31000 / 60000]	Loss: 0.116732
# Training Epoch: 2 [32000 / 60000]	Loss: 0.121289
# Training Epoch: 2 [33000 / 60000]	Loss: 0.074651
# Training Epoch: 2 [34000 / 60000]	Loss: 0.124226
# Training Epoch: 2 [35000 / 60000]	Loss: 0.072712
# Training Epoch: 2 [36000 / 60000]	Loss: 0.124178
# Training Epoch: 2 [37000 / 60000]	Loss: 0.094450
# Training Epoch: 2 [38000 / 60000]	Loss: 0.089905
# Training Epoch: 2 [39000 / 60000]	Loss: 0.064386
# Training Epoch: 2 [40000 / 60000]	Loss: 0.145745
# Training Epoch: 2 [41000 / 60000]	Loss: 0.085337
# Training Epoch: 2 [42000 / 60000]	Loss: 0.137037
# Training Epoch: 2 [43000 / 60000]	Loss: 0.071016
# Training Epoch: 2 [44000 / 60000]	Loss: 0.065346
# Training Epoch: 2 [45000 / 60000]	Loss: 0.108501
# Training Epoch: 2 [46000 / 60000]	Loss: 0.091337
# Training Epoch: 2 [47000 / 60000]	Loss: 0.123812
# Training Epoch: 2 [48000 / 60000]	Loss: 0.107017
# Training Epoch: 2 [49000 / 60000]	Loss: 0.133687
# Training Epoch: 2 [50000 / 60000]	Loss: 0.084937
# Training Epoch: 2 [51000 / 60000]	Loss: 0.096436
# Training Epoch: 2 [52000 / 60000]	Loss: 0.113860
# Training Epoch: 2 [53000 / 60000]	Loss: 0.106258
# Training Epoch: 2 [54000 / 60000]	Loss: 0.121392
# Training Epoch: 4 [33000 / 60000]	Loss: 0.146652
# Training Epoch: 4 [34000 / 60000]	Loss: 0.078672
# Training Epoch: 4 [35000 / 60000]	Loss: 0.071466
# Training Epoch: 4 [36000 / 60000]	Loss: 0.107650
# Training Epoch: 4 [37000 / 60000]	Loss: 0.133506
# Training Epoch: 4 [38000 / 60000]	Loss: 0.077600
# Training Epoch: 4 [39000 / 60000]	Loss: 0.043774
# Training Epoch: 4 [40000 / 60000]	Loss: 0.071402
# Training Epoch: 4 [41000 / 60000]	Loss: 0.054018
# Training Epoch: 4 [42000 / 60000]	Loss: 0.104128
# Training Epoch: 4 [43000 / 60000]	Loss: 0.110600
# Training Epoch: 4 [44000 / 60000]	Loss: 0.053750
# Training Epoch: 4 [45000 / 60000]	Loss: 0.040499
# Training Epoch: 4 [46000 / 60000]	Loss: 0.083959
# Training Epoch: 4 [47000 / 60000]	Loss: 0.072255
# Training Epoch: 4 [48000 / 60000]	Loss: 0.090914
# Training Epoch: 4 [49000 / 60000]	Loss: 0.079399
# Training Epoch: 4 [50000 / 60000]	Loss: 0.098115
# Training Epoch: 4 [51000 / 60000]	Loss: 0.111754
# Training Epoch: 4 [52000 / 60000]	Loss: 0.103358
# Training Epoch: 4 [53000 / 60000]	Loss: 0.104418
# Training Epoch: 4 [54000 / 60000]	Loss: 0.096108
# Training Epoch: 4 [55000 / 60000]	Loss: 0.071453
# Training Epoch: 4 [56000 / 60000]	Loss: 0.103418
# Training Epoch: 4 [57000 / 60000]	Loss: 0.097146
# Training Epoch: 4 [58000 / 60000]	Loss: 0.129603
# Training Epoch: 4 [59000 / 60000]	Loss: 0.105591
# ----- Epoch: 4 Average loss: 0.0895
# ----- Test set loss: 887.7594
# Training Epoch: 5 [0 / 60000]	Loss: 0.104507
# Training Epoch: 5 [1000 / 60000]	Loss: 0.088039
# Training Epoch: 5 [2000 / 60000]	Loss: 0.088293
# Training Epoch: 5 [3000 / 60000]	Loss: 0.100216
# Training Epoch: 5 [4000 / 60000]	Loss: 0.115070
# Training Epoch: 5 [5000 / 60000]	Loss: 0.134381
# Training Epoch: 5 [6000 / 60000]	Loss: 0.101388
# Training Epoch: 5 [7000 / 60000]	Loss: 0.092002
# Training Epoch: 5 [8000 / 60000]	Loss: 0.120373
# Training Epoch: 5 [9000 / 60000]	Loss: 0.070238
# Training Epoch: 5 [10000 / 60000]	Loss: 0.056700
# Training Epoch: 5 [11000 / 60000]	Loss: 0.103269
# Training Epoch: 5 [12000 / 60000]	Loss: 0.099992
# Training Epoch: 5 [13000 / 60000]	Loss: 0.121079
# Training Epoch: 5 [14000 / 60000]	Loss: 0.064125
# Training Epoch: 5 [15000 / 60000]	Loss: 0.100762
# Training Epoch: 5 [16000 / 60000]	Loss: 0.122752
# Training Epoch: 5 [17000 / 60000]	Loss: 0.079954
# Training Epoch: 5 [18000 / 60000]	Loss: 0.082988
# Training Epoch: 5 [19000 / 60000]	Loss: 0.078209
# Training Epoch: 5 [20000 / 60000]	Loss: 0.039407
# Training Epoch: 5 [21000 / 60000]	Loss: 0.079664
# Training Epoch: 7 [50000 / 60000]	Loss: 0.061853
# Training Epoch: 7 [51000 / 60000]	Loss: 0.079363
# Training Epoch: 7 [52000 / 60000]	Loss: 0.101338
# Training Epoch: 7 [53000 / 60000]	Loss: 0.077036
# Training Epoch: 7 [54000 / 60000]	Loss: 0.124546
# Training Epoch: 7 [55000 / 60000]	Loss: 0.100721
# Training Epoch: 7 [56000 / 60000]	Loss: 0.082742
# Training Epoch: 7 [57000 / 60000]	Loss: 0.060281
# Training Epoch: 7 [58000 / 60000]	Loss: 0.079756
# Training Epoch: 7 [59000 / 60000]	Loss: 0.141375
# ----- Epoch: 7 Average loss: 0.0907
# ----- Test set loss: 900.9404
# Training Epoch: 8 [0 / 60000]	Loss: 0.072251
# Training Epoch: 8 [1000 / 60000]	Loss: 0.092211
# Training Epoch: 8 [2000 / 60000]	Loss: 0.112978
# Training Epoch: 8 [3000 / 60000]	Loss: 0.053693
# Training Epoch: 8 [4000 / 60000]	Loss: 0.104528
# Training Epoch: 8 [5000 / 60000]	Loss: 0.055874
# Training Epoch: 8 [6000 / 60000]	Loss: 0.139778
# Training Epoch: 8 [7000 / 60000]	Loss: 0.083845
# Training Epoch: 8 [8000 / 60000]	Loss: 0.103722
# Training Epoch: 8 [9000 / 60000]	Loss: 0.055572
# Training Epoch: 8 [10000 / 60000]	Loss: 0.155751
# Training Epoch: 8 [11000 / 60000]	Loss: 0.125266
# Training Epoch: 8 [12000 / 60000]	Loss: 0.084561
# Training Epoch: 8 [13000 / 60000]	Loss: 0.097097
# Training Epoch: 8 [14000 / 60000]	Loss: 0.073509
# Training Epoch: 8 [15000 / 60000]	Loss: 0.089947
# Training Epoch: 8 [16000 / 60000]	Loss: 0.111912
# Training Epoch: 8 [17000 / 60000]	Loss: 0.129800
# Training Epoch: 8 [18000 / 60000]	Loss: 0.060780
# Training Epoch: 8 [19000 / 60000]	Loss: 0.125987
# Training Epoch: 8 [20000 / 60000]	Loss: 0.082260
# Training Epoch: 8 [21000 / 60000]	Loss: 0.075030
# Training Epoch: 8 [22000 / 60000]	Loss: 0.174977
# Training Epoch: 8 [23000 / 60000]	Loss: 0.098121
# Training Epoch: 8 [24000 / 60000]	Loss: 0.120024
# Training Epoch: 8 [25000 / 60000]	Loss: 0.071131
# Training Epoch: 8 [26000 / 60000]	Loss: 0.109862
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-65-c4974c906c45> in <module>
#       1 for epoch in range(1, 11):
# ----> 2     train(epoch)
#       3     test()
#
# <ipython-input-64-16c7da2406fc> in train(epoch)
#       5         batchLoss = torch.sum(model.loss(target, predictions))
#       6         trainingLoss += batchLoss
# ----> 7         model.update(data, target, predictions)
#       8         if index % 10 == 0:
#       9             print(f'Training Epoch: {epoch} [{index * len(data)} / {len(trainData)}]\tLoss: {(batchLoss / len(data)):.6f}')
#
# <ipython-input-63-302b768c4203> in update(self, x, y, p)
#      27         sum /= p.shape[0]
#      28         for i in range(self.weights.shape[0]):
# ---> 29             self.weights[i] -= self.learningRate * sum[i]
#      30
#      31 model = Perceptron(0, 1e-3)
#
# KeyboardInterrupt:
